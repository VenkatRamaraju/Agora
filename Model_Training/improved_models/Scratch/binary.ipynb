# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten
from keras.optimizers import RMSprop
from keras.datasets import fashion_mnist
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# %%
training_df = pd.read_csv('ds.csv', index_col=0)

# %%
X = training_df[['headline_polarity', 'convo_polarity', 'forwardEps','bookValue', 'heldPercentInstitutions', 
        'shortRatio', 'shortPercentOfFloat']]
y = training_df['Buy']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
print(models)
# Out:
# 100%|██████████| 29/29 [00:01<00:00, 24.44it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# RandomForestClassifier             0.90               0.90     0.90      0.90
# XGBClassifier                      0.90               0.89     0.89      0.90
# AdaBoostClassifier                 0.90               0.88     0.88      0.90
# ExtraTreesClassifier               0.89               0.88     0.88      0.89
# LGBMClassifier                     0.89               0.88     0.88      0.89
# DecisionTreeClassifier             0.87               0.85     0.85      0.87
# BaggingClassifier                  0.87               0.85     0.85      0.87
# KNeighborsClassifier               0.87               0.84     0.84      0.87
# ExtraTreeClassifier                0.84               0.83     0.83      0.84
# SVC                                0.87               0.82     0.82      0.86
# BernoulliNB                        0.85               0.82     0.82      0.85
# NuSVC                              0.85               0.80     0.80      0.84
# LabelSpreading                     0.80               0.77     0.77      0.80
# QuadraticDiscriminantAnalysis      0.72               0.77     0.77      0.73
# GaussianNB                         0.72               0.77     0.77      0.72
# LabelPropagation                   0.80               0.76     0.76      0.79
# NearestCentroid                    0.71               0.68     0.68      0.71
# Perceptron                         0.69               0.62     0.62      0.68
# PassiveAggressiveClassifier        0.68               0.57     0.57      0.62
# LogisticRegression                 0.67               0.56     0.56      0.62
# SGDClassifier                      0.66               0.56     0.56      0.62
# LinearSVC                          0.66               0.55     0.55      0.61
# LinearDiscriminantAnalysis         0.67               0.55     0.55      0.60
# RidgeClassifierCV                  0.67               0.54     0.54      0.59
# RidgeClassifier                    0.67               0.54     0.54      0.59
# DummyClassifier                    0.56               0.53     0.53      0.56
# CalibratedClassifierCV             0.66               0.51     0.51      0.55
#
#                                Time Taken
# Model
# RandomForestClassifier               0.15
# XGBClassifier                        0.11
# AdaBoostClassifier                   0.11
# ExtraTreesClassifier                 0.14
# LGBMClassifier                       0.12
# DecisionTreeClassifier               0.01
# BaggingClassifier                    0.03
# KNeighborsClassifier                 0.02
# ExtraTreeClassifier                  0.02
# SVC                                  0.02
# BernoulliNB                          0.01
# NuSVC                                0.04
# LabelSpreading                       0.04
# QuadraticDiscriminantAnalysis        0.01
# GaussianNB                           0.01
# LabelPropagation                     0.03
# NearestCentroid                      0.01
# Perceptron                           0.01
# PassiveAggressiveClassifier          0.01
# LogisticRegression                   0.01
# SGDClassifier                        0.01
# LinearSVC                            0.06
# LinearDiscriminantAnalysis           0.01
# RidgeClassifierCV                    0.01
# RidgeClassifier                      0.01
# DummyClassifier                      0.01
# CalibratedClassifierCV               0.14

# %%
training_df
# Out:
#       headline_polarity  convo_polarity  beta  profitMargins  forwardEps  \
# 0                  0.48            0.45  1.73           0.05        0.41
# 1                  0.61            0.47  1.30           0.06        0.53
# 8                  0.40            0.38  1.73           0.01        0.41
# 9                  0.48            0.45  1.73           0.01        0.41
# 11                 0.48            0.45  1.73           0.01        0.41
# ...                 ...             ...   ...            ...         ...
# 4320               0.41            0.28  1.73           0.01        0.41
# 4321               0.56            0.39  0.29          -0.57        0.38
# 4322               0.57            0.29  1.73           0.01        0.41
# 4323               0.69            0.47  1.73           0.07        0.39
# 4324               0.72            0.26  1.73          -0.36        0.41
#
#       bookValue  heldPercentInstitutions  shortRatio  shortPercentOfFloat  Buy
# 0          0.01                     0.18        0.07                 0.05    1
# 1          0.01                     0.18        0.15                 0.12    1
# 8          0.01                     0.13        0.20                 0.15    1
# 9          0.01                     0.11        0.10                 0.10    1
# 11         0.01                     0.11        0.10                 0.10    1
# ...         ...                      ...         ...                  ...  ...
# 4320       0.01                     0.11        0.10                 0.10    0
# 4321       0.01                     0.00        0.00                 0.10    0
# 4322       0.01                     0.11        0.10                 0.10    0
# 4323       0.01                     0.02        0.09                 0.10    0
# 4324       0.00                     0.02        0.01                 0.10    0
#
# [1246 rows x 10 columns]
